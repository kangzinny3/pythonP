# %%
import urllib.request
import json

# %%
movieDate = '20191007'
key = 'c1259d1034a8d753877bf1eac2f78cc9'
url = f'http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchDailyBoxOfficeList.json?key=c1259d1034a8d753877bf1eac2f78cc9&targetDt={movieDate}'
response = urllib.request.urlopen(url)

rescode = response.getcode()
if (rescode == 200):
    responseData = response.read()
    
result = json.loads(responseData)
pre_result = result['boxOfficeResult']['dailyBoxOfficeList']

for i in range(0, len(pre_result)):
    pre_result[i]['targetDt'] = movieDate

# %%
result
# Out:
# {'boxOfficeResult': {'boxofficeType': '일별 박스오피스',
#   'showRange': '20191007~20191007',
#   'dailyBoxOfficeList': [{'rnum': '1',
#     'rank': '1',
#     'rankInten': '0',
#     'rankOldAndNew': 'OLD',
#     'movieCd': '20199950',
#     'movieNm': '조커',
#     'openDt': '2019-10-02',
#     'salesAmt': '1386982140',
#     'salesShare': '49.4',
#     'salesInten': '-2309455870',
#     'salesChange': '-62.5',
#     'salesAcc': '20740008050',
#     'audiCnt': '167699',
#     'audiInten': '-247151',
#     'audiChange': '-59.6',
#     'audiAcc': '2367535',
#     'scrnCnt': '1293',
#     'showCnt': '6500'},
#    {'rnum': '2',
#     'rank': '2',
#     'rankInten': '0',
#     'rankOldAndNew': 'OLD',
#     'movieCd': '20195920',
#     'movieNm': '가장 보통의 연애',
#     'openDt': '2019-10-02',
#     'salesAmt': '794886970',
#     'salesShare': '28.3',
#     'salesInten': '-1106355660',
#     'salesChange': '-58.2',
#     'salesAcc': '9921111850',
#     'audiCnt': '98738',
#     'audiInten': '-118239',
#     'audiChange': '-54.5',
#     'audiAcc': '1163222',
#     'scrnCnt': '1012',
#     'showCnt': '5012'},
#    {'rnum': '3',
#     'rank': '3',
#     'rankInten': '0',
#     'rankOldAndNew': 'OLD',
#     'movieCd': '20184483',
#     'movieNm': '퍼펙트맨',
#     'openDt': '2019-10-02',
#     'salesAmt': '373285070',
#     'salesShare': '13.3',
#     'salesInten': '-635892060',
#     'salesChange': '-63',
#     'salesAcc': '5907799350',
#     'audiCnt': '46972',
#     'audiInten': '-68864',
#     'audiChange': '-59.4',
#     'audiAcc': '711272',
#     'scrnCnt': '780',
#     'showCnt': '3071'},
#    {'rnum': '4',
#     'rank': '4',
#     'rankInten': '0',
#     'rankOldAndNew': 'OLD',
#     'movieCd': '20193601',
#     'movieNm': '장사리 : 잊혀진 영웅들',
#     'openDt': '2019-09-25',
#     'salesAmt': '90263400',
#     'salesShare': '3.2',
#     'salesInten': '-187674420',
#     'salesChange': '-67.5',
#     'salesAcc': '8352025650',
#     'audiCnt': '12036',
#     'audiInten': '-21189',
#     'audiChange': '-63.8',
#     'audiAcc': '1050150',
#     'scrnCnt': '567',
#     'showCnt': '1431'},
#    {'rnum': '5',
#     'rank': '5',
#     'rankInten': '2',
#     'rankOldAndNew': 'OLD',
#     'movieCd': '20194456',
#     'movieNm': '양자물리학',
#     'openDt': '2019-09-25',
#     'salesAmt': '24664420',
#     'salesShare': '0.9',
#     'salesInten': '-28527260',
#     'salesChange': '-53.6',
#     'salesAcc': '4461218540',
#     'audiCnt': '3132',
#     'audiInten': '-3050',
#     'audiChange': '-49.3',
#     'audiAcc': '545785',
#     'scrnCnt': '362',
#     'showCnt': '607'},
#    {'rnum': '6',
#     'rank': '6',
#     'rankInten': '2',
#     'rankOldAndNew': 'OLD',
#     'movieCd': '20188750',
#     'movieNm': '나쁜 녀석들: 더 무비',
#     'openDt': '2019-09-11',
#     'salesAmt': '18681800',
#     'salesShare': '0.7',
#     'salesInten': '-19798890',
#     'salesChange': '-51.5',
#     'salesAcc': '39464481084',
#     'audiCnt': '2362',
#     'audiInten': '-2079',
#     'audiChange': '-46.8',
#     'audiAcc': '4559058',
#     'scrnCnt': '287',
#     'showCnt': '446'},
#    {'rnum': '7',
#     'rank': '7',
#     'rankInten': '2',
#     'rankOldAndNew': 'OLD',
#     'movieCd': '20199446',
#     'movieNm': '원스 어폰 어 타임... 인 할리우드',
#     'openDt': '2019-09-25',
#     'salesAmt': '16194300',
#     'salesShare': '0.6',
#     'salesInten': '-21345700',
#     'salesChange': '-56.9',
#     'salesAcc': '2121054970',
#     'audiCnt': '2032',
#     'audiInten': '-2121',
#     'audiChange': '-51.1',
#     'audiAcc': '260173',
#     'scrnCnt': '136',
#     'showCnt': '222'},
#    {'rnum': '8',
#     'rank': '8',
#     'rankInten': '0',
#     'rankOldAndNew': 'NEW',
#     'movieCd': '20191183',
#     'movieNm': '제미니 맨',
#     'openDt': '2019-10-09',
#     'salesAmt': '20568000',
#     'salesShare': '0.7',
#     'salesInten': '20568000',
#     'salesChange': '100',
#     'salesAcc': '78672000',
#     'audiCnt': '1724',
#     'audiInten': '1724',
#     'audiChange': '100',
#     'audiAcc': '8170',
#     'scrnCnt': '5',
#     'showCnt': '5'},
#    {'rnum': '9',
#     'rank': '9',
#     'rankInten': '-4',
#     'rankOldAndNew': 'OLD',
#     'movieCd': '20195941',
#     'movieNm': '소피와 드래곤: 마법책의 비밀',
#     'openDt': '2019-10-02',
#     'salesAmt': '8575500',
#     'salesShare': '0.3',
#     'salesInten': '-85740740',
#     'salesChange': '-90.9',
#     'salesAcc': '558533830',
#     'audiCnt': '1177',
#     'audiInten': '-10673',
#     'audiChange': '-90.1',
#     'audiAcc': '71597',
#     'scrnCnt': '233',
#     'showCnt': '258'},
#    {'rnum': '10',
#     'rank': '10',
#     'rankInten': '-4',
#     'rankOldAndNew': 'OLD',
#     'movieCd': '20196380',
#     'movieNm': '몬스터 하우스',
#     'openDt': '2019-10-03',
#     'salesAmt': '7224100',
#     'salesShare': '0.3',
#     'salesInten': '-47917300',
#     'salesChange': '-86.9',
#     'salesAcc': '312627800',
#     'audiCnt': '1055',
#     'audiInten': '-5602',
#     'audiChange': '-84.2',
#     'audiAcc': '39053',
#     'scrnCnt': '105',
#     'showCnt': '120'}]}}

# %%
pre_result
# Out:
# [{'rnum': '1',
#   'rank': '1',
#   'rankInten': '0',
#   'rankOldAndNew': 'OLD',
#   'movieCd': '20199950',
#   'movieNm': '조커',
#   'openDt': '2019-10-02',
#   'salesAmt': '1386982140',
#   'salesShare': '49.4',
#   'salesInten': '-2309455870',
#   'salesChange': '-62.5',
#   'salesAcc': '20740008050',
#   'audiCnt': '167699',
#   'audiInten': '-247151',
#   'audiChange': '-59.6',
#   'audiAcc': '2367535',
#   'scrnCnt': '1293',
#   'showCnt': '6500'},
#  {'rnum': '2',
#   'rank': '2',
#   'rankInten': '0',
#   'rankOldAndNew': 'OLD',
#   'movieCd': '20195920',
#   'movieNm': '가장 보통의 연애',
#   'openDt': '2019-10-02',
#   'salesAmt': '794886970',
#   'salesShare': '28.3',
#   'salesInten': '-1106355660',
#   'salesChange': '-58.2',
#   'salesAcc': '9921111850',
#   'audiCnt': '98738',
#   'audiInten': '-118239',
#   'audiChange': '-54.5',
#   'audiAcc': '1163222',
#   'scrnCnt': '1012',
#   'showCnt': '5012'},
#  {'rnum': '3',
#   'rank': '3',
#   'rankInten': '0',
#   'rankOldAndNew': 'OLD',
#   'movieCd': '20184483',
#   'movieNm': '퍼펙트맨',
#   'openDt': '2019-10-02',
#   'salesAmt': '373285070',
#   'salesShare': '13.3',
#   'salesInten': '-635892060',
#   'salesChange': '-63',
#   'salesAcc': '5907799350',
#   'audiCnt': '46972',
#   'audiInten': '-68864',
#   'audiChange': '-59.4',
#   'audiAcc': '711272',
#   'scrnCnt': '780',
#   'showCnt': '3071'},
#  {'rnum': '4',
#   'rank': '4',
#   'rankInten': '0',
#   'rankOldAndNew': 'OLD',
#   'movieCd': '20193601',
#   'movieNm': '장사리 : 잊혀진 영웅들',
#   'openDt': '2019-09-25',
#   'salesAmt': '90263400',
#   'salesShare': '3.2',
#   'salesInten': '-187674420',
#   'salesChange': '-67.5',
#   'salesAcc': '8352025650',
#   'audiCnt': '12036',
#   'audiInten': '-21189',
#   'audiChange': '-63.8',
#   'audiAcc': '1050150',
#   'scrnCnt': '567',
#   'showCnt': '1431'},
#  {'rnum': '5',
#   'rank': '5',
#   'rankInten': '2',
#   'rankOldAndNew': 'OLD',
#   'movieCd': '20194456',
#   'movieNm': '양자물리학',
#   'openDt': '2019-09-25',
#   'salesAmt': '24664420',
#   'salesShare': '0.9',
#   'salesInten': '-28527260',
#   'salesChange': '-53.6',
#   'salesAcc': '4461218540',
#   'audiCnt': '3132',
#   'audiInten': '-3050',
#   'audiChange': '-49.3',
#   'audiAcc': '545785',
#   'scrnCnt': '362',
#   'showCnt': '607'},
#  {'rnum': '6',
#   'rank': '6',
#   'rankInten': '2',
#   'rankOldAndNew': 'OLD',
#   'movieCd': '20188750',
#   'movieNm': '나쁜 녀석들: 더 무비',
#   'openDt': '2019-09-11',
#   'salesAmt': '18681800',
#   'salesShare': '0.7',
#   'salesInten': '-19798890',
#   'salesChange': '-51.5',
#   'salesAcc': '39464481084',
#   'audiCnt': '2362',
#   'audiInten': '-2079',
#   'audiChange': '-46.8',
#   'audiAcc': '4559058',
#   'scrnCnt': '287',
#   'showCnt': '446'},
#  {'rnum': '7',
#   'rank': '7',
#   'rankInten': '2',
#   'rankOldAndNew': 'OLD',
#   'movieCd': '20199446',
#   'movieNm': '원스 어폰 어 타임... 인 할리우드',
#   'openDt': '2019-09-25',
#   'salesAmt': '16194300',
#   'salesShare': '0.6',
#   'salesInten': '-21345700',
#   'salesChange': '-56.9',
#   'salesAcc': '2121054970',
#   'audiCnt': '2032',
#   'audiInten': '-2121',
#   'audiChange': '-51.1',
#   'audiAcc': '260173',
#   'scrnCnt': '136',
#   'showCnt': '222'},
#  {'rnum': '8',
#   'rank': '8',
#   'rankInten': '0',
#   'rankOldAndNew': 'NEW',
#   'movieCd': '20191183',
#   'movieNm': '제미니 맨',
#   'openDt': '2019-10-09',
#   'salesAmt': '20568000',
#   'salesShare': '0.7',
#   'salesInten': '20568000',
#   'salesChange': '100',
#   'salesAcc': '78672000',
#   'audiCnt': '1724',
#   'audiInten': '1724',
#   'audiChange': '100',
#   'audiAcc': '8170',
#   'scrnCnt': '5',
#   'showCnt': '5'},
#  {'rnum': '9',
#   'rank': '9',
#   'rankInten': '-4',
#   'rankOldAndNew': 'OLD',
#   'movieCd': '20195941',
#   'movieNm': '소피와 드래곤: 마법책의 비밀',
#   'openDt': '2019-10-02',
#   'salesAmt': '8575500',
#   'salesShare': '0.3',
#   'salesInten': '-85740740',
#   'salesChange': '-90.9',
#   'salesAcc': '558533830',
#   'audiCnt': '1177',
#   'audiInten': '-10673',
#   'audiChange': '-90.1',
#   'audiAcc': '71597',
#   'scrnCnt': '233',
#   'showCnt': '258'},
#  {'rnum': '10',
#   'rank': '10',
#   'rankInten': '-4',
#   'rankOldAndNew': 'OLD',
#   'movieCd': '20196380',
#   'movieNm': '몬스터 하우스',
#   'openDt': '2019-10-03',
#   'salesAmt': '7224100',
#   'salesShare': '0.3',
#   'salesInten': '-47917300',
#   'salesChange': '-86.9',
#   'salesAcc': '312627800',
#   'audiCnt': '1055',
#   'audiInten': '-5602',
#   'audiChange': '-84.2',
#   'audiAcc': '39053',
#   'scrnCnt': '105',
#   'showCnt': '120'}]

# %%
# https://docs.python.org/3/library/datetime.html
import datetime

# %%
movieDate = '20191007'
datetime_obj = datetime.datetime.strptime(movieDate, '%Y%m%d').date()
datetime_obj_tmp = datetime_obj - datetime.timedelta(days=1)   # weeks=1
movieDate = datetime_obj_tmp.strftime('%Y%m%d')

# %%
print(type(movieDate))
print(movieDate)
# Out:
# <class 'str'>
# 20191006

# %%
print(type(datetime_obj))
print(datetime_obj)
print(type(datetime_obj_tmp))
print(datetime_obj_tmp)
# Out:
# <class 'datetime.date'>
# 2019-10-07
# <class 'datetime.date'>
# 2019-10-06

# %%
df = DataFrame(result['boxOfficeResult']['dailyBoxOfficeList'])
